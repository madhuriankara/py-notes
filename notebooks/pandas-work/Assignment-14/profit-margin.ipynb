# %%
#Calculate the profit margin for each food item, assuming a fixed cost of 70% of the Price.

# %%
import pandas as pd

# %%
food = pd.read_csv('food.csv')

# %%
food_sales = pd.read_csv('food_sales.csv')

# %%
ratings = pd.read_csv('ratings.csv')

# %%
df = pd.merge(food, food_sales, on='Food_Name', how='outer')

# %%
df = pd.merge(df, ratings, on='Food_Name', how='outer')

# %%
df
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating
# 0     4.0
# 1     3.9
# 2     4.8
# 3     3.8
# 4     4.5
# 5     4.6
# 6     4.3
# 7     4.4
# 8     4.7
# 9     4.2

# %%
df['Cost'] = df['Price']* 0.70

# %%
df['Cost']
# Out:
# 0     3.843
# 1     4.193
# 2     2.793
# 3     5.593
# 4     6.293
# 5     3.493
# 6     2.443
# 7    10.493
# 8     9.093
# 9     4.893
# Name: Cost, dtype: float64

# %%
df
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit    Cost
# 0     4.0   3.843   3.843
# 1     3.9   4.193   4.193
# 2     4.8   2.793   2.793
# 3     3.8   5.593   5.593
# 4     4.5   6.293   6.293
# 5     4.6   3.493   3.493
# 6     4.3   2.443   2.443
# 7     4.4  10.493  10.493
# 8     4.7   9.093   9.093
# 9     4.2   4.893   4.893

# %%
df['Profit_Margin'] = ((df['Price'] - df['Cost']) / df['Price']) * 100

# %%
df['Profit_Margin']
# Out:
# 0    30.0
# 1    30.0
# 2    30.0
# 3    30.0
# 4    30.0
# 5    30.0
# 6    30.0
# 7    30.0
# 8    30.0
# 9    30.0
# Name: Profit_Margin, dtype: float64

# %%
df
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit    Cost  Profit_Margin
# 0     4.0   3.843   3.843           30.0
# 1     3.9   4.193   4.193           30.0
# 2     4.8   2.793   2.793           30.0
# 3     3.8   5.593   5.593           30.0
# 4     4.5   6.293   6.293           30.0
# 5     4.6   3.493   3.493           30.0
# 6     4.3   2.443   2.443           30.0
# 7     4.4  10.493  10.493           30.0
# 8     4.7   9.093   9.093           30.0
# 9     4.2   4.893   4.893           30.0

# %%
df.drop('Profit_Margin',axis = 1)
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit    Cost
# 0     4.0   3.843   3.843
# 1     3.9   4.193   4.193
# 2     4.8   2.793   2.793
# 3     3.8   5.593   5.593
# 4     4.5   6.293   6.293
# 5     4.6   3.493   3.493
# 6     4.3   2.443   2.443
# 7     4.4  10.493  10.493
# 8     4.7   9.093   9.093
# 9     4.2   4.893   4.893

# %%
df.drop('Profit',axis = 1)
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating    Cost  Profit_Margin
# 0     4.0   3.843           30.0
# 1     3.9   4.193           30.0
# 2     4.8   2.793           30.0
# 3     3.8   5.593           30.0
# 4     4.5   6.293           30.0
# 5     4.6   3.493           30.0
# 6     4.3   2.443           30.0
# 7     4.4  10.493           30.0
# 8     4.7   9.093           30.0
# 9     4.2   4.893           30.0

# %%
df.drop('Profit_Margin',axis = 1)
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit    Cost
# 0     4.0   3.843   3.843
# 1     3.9   4.193   4.193
# 2     4.8   2.793   2.793
# 3     3.8   5.593   5.593
# 4     4.5   6.293   6.293
# 5     4.6   3.493   3.493
# 6     4.3   2.443   2.443
# 7     4.4  10.493  10.493
# 8     4.7   9.093   9.093
# 9     4.2   4.893   4.893

# %%
df.drop('Cost',axis = 1)
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit  Profit_Margin
# 0     4.0   3.843           30.0
# 1     3.9   4.193           30.0
# 2     4.8   2.793           30.0
# 3     3.8   5.593           30.0
# 4     4.5   6.293           30.0
# 5     4.6   3.493           30.0
# 6     4.3   2.443           30.0
# 7     4.4  10.493           30.0
# 8     4.7   9.093           30.0
# 9     4.2   4.893           30.0

# %%
df
# Out:
#    Food_ID   Food_Name   Category  Price  Calories Available  Units_Sold  \
# 0        2      Burger  Fast Food   5.49       450       Yes         200
# 1        7  Fried Rice      Asian   5.99       350       Yes         100
# 2        8   Ice Cream    Dessert   3.99       200       Yes         400
# 3        3       Pasta    Italian   7.99       400        No         150
# 4        1       Pizza  Fast Food   8.99       300       Yes         120
# 5        6       Salad    Healthy   4.99       150       Yes         300
# 6       10        Soup    Healthy   3.49       100       Yes         250
# 7        9       Steak      Grill  14.99       700        No          80
# 8        4       Sushi   Japanese  12.99       250       Yes          50
# 9        5       Tacos    Mexican   6.99       200        No         180
#
#    Rating  Profit    Cost  Profit_Margin
# 0     4.0   3.843   3.843           30.0
# 1     3.9   4.193   4.193           30.0
# 2     4.8   2.793   2.793           30.0
# 3     3.8   5.593   5.593           30.0
# 4     4.5   6.293   6.293           30.0
# 5     4.6   3.493   3.493           30.0
# 6     4.3   2.443   2.443           30.0
# 7     4.4  10.493  10.493           30.0
# 8     4.7   9.093   9.093           30.0
# 9     4.2   4.893   4.893           30.0
